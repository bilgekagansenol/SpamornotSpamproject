# %% [markdown]
# <a href="https://colab.research.google.com/github/bilgekagansenol/SpamornotSpamproject/blob/main/spamornotspam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt',force=True)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

file_path = r"/content/drive/MyDrive/spamornotspamproject/emails/emails.csv"
if os.path.isfile(file_path):
    print("folder is found")
else:
    print("path is wrong or folder is not exist")
# Out:
# folder is found

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
df['tokenized_text'] = df['text'].apply(nltk.word_tokenize)

# %%
df.head()
# Out:
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [Subject, :, naturally, irresistible, your, co...
# 1  [Subject, :, the, stock, trading, gunslinger, ...
# 2  [Subject, :, unbelievable, new, homes, made, e...
# 3  [Subject, :, 4, color, printing, special, requ...
# 4  [Subject, :, do, not, have, money, ,, get, sof...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import os
# !git clone https://github.com/bilgekagansenol/SpamornotSpamproject

os.chdir('/content/SpamornotSpamproject')
# Out:
# Cloning into 'SpamornotSpamproject'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 58 (delta 29), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 248.16 KiB | 9.54 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !ls
# Out:
# functions_cleaning_tokens.py  functions.ipynb  spamornotspam.ipynb

# %%
import functions_cleaning_tokens

df['tokenized_text'] = df['tokenized_text'].apply(functions_cleaning_tokens.clean_tokens)
df.head()
# Out:
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [subject, naturally, irresistible, your, corpo...
# 1  [subject, the, stock, trading, gunslinger, fan...
# 2  [subject, unbelievable, new, homes, made, easy...
# 3  [subject, color, printing, special, request, a...
# 4  [subject, do, not, have, money, get, software,...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk


nltk.download('stopwords')

stopwords1 = stopwords.words('english')
print(stopwords1)
list_of_tokens  = []
list_of_tokens = df['tokenized_text'].tolist()
cleaned_samples = [sample[1:] if sample and sample[0].lower() == 'subject' else sample for sample in list_of_tokens]
list_of_tokens = cleaned_samples
list_of_tokens = [token for token in list_of_tokens if token not in stopwords1 ]
df['tokenized_text'] = list_of_tokens
df.head()
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# !pip install gensim
from gensim.models import Word2Vec

# %%
mails = df['tokenized_text'].tolist()
model1 = Word2Vec(sentences=mails, vector_size=100, window=5, min_count=1, workers=4)
model2 = Word2Vec(sentences=mails, vector_size=100, window=5, min_count=2, workers=4)
model5= Word2Vec(sentences=mails, vector_size=100, window=5, min_count=5, workers=4)
model1.save("word2vec1.model")
model2.save("word2vec2.model")
model5.save("word2vec5.model")

# %%
import numpy as np
import pandas as pd
mails = df['tokenized_text'].tolist()
model1 = Word2Vec.load("word2vec1.model")
model2 = Word2Vec.load("word2vec2.model")
model5 = Word2Vec.load("word2vec5.model")


import numpy as np

def word2vec_vector(tokens_list, model):
    vector_tokens = []  # Her mail için bir ortalama vektör saklayacak liste

    for tokens in tokens_list:  # Mail bazında döngü
        vectors = []  # Maildeki kelimelerin vektörlerini saklamak için liste

        # Mail içindeki her kelime için
        for token in tokens:
            if token in model.wv:  # Eğer kelime Word2Vec modelinde varsa
                vectors.append(model.wv[token])

        # Mailin ortalamasını al
        if len(vectors) > 0:
            mail_vector = np.mean(vectors, axis=0)  # Kelime vektörlerinin ortalaması
        else:
            mail_vector = np.zeros(model.vector_size)  # Hiç geçerli kelime yoksa sıfır vektör

        vector_tokens.append(mail_vector)  # Mailin ortalama vektörünü ekle

    return vector_tokens


vector1 =np.array(word2vec_vector(mails,model1))
vector2 =np.array(word2vec_vector(mails,model2))
vector5 =np.array(word2vec_vector(mails,model5))

# %%
import numpy as np
np.save('/content/drive/MyDrive/spamornotspamproject/vector1.npy',vector1)
np.save('/content/drive/MyDrive/spamornotspamproject/vector2.npy',vector2)
np.save('/content/drive/MyDrive/spamornotspamproject/vector5.npy',vector5)

# %%
import numpy as np

# vector1'in her öğesinin sabit boyutlu olduğundan emin olun
print(type(vector1))  # list olmalı
print(type(vector1[0]))  # numpy.ndarray olmalı
print(vector1[0].shape)  # (vector_size,) şeklinde sabit boyutta olmalı
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (100,)

# %%
# !pip install scikit-learn

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X1 = vector1
X2 = vector2
X5 = vector5
y = df['spam'].tolist()
print("X1 shape:", len(X1))
print("X2 shape",len(X2))
print("X5 shape",len(X5))
print("y shape:", len(y))
print("Vector1 shape:", np.array(vector1).shape)
print("y (df['spam']) length:", len(y))
# Out:
# X1 shape: 5728
# X2 shape 5728
# X5 shape 5728
# y shape: 5728
# Vector1 shape: (5728, 100)
# y (df['spam']) length: 5728

# %%
import numpy as np
saved_vector1 = np.load('/content/drive/MyDrive/spamornotspamproject/vector1.npy')
saved_vector2 = np.load('/content/drive/MyDrive/spamornotspamproject/vector2.npy')
saved_vector5 = np.load('/content/drive/MyDrive/spamornotspamproject/vector5.npy')
X1 = saved_vector1
X2 = saved_vector2
X5 = saved_vector5
y = df['spam'].tolist()
print("X1 shape:", len(X1))
print("X2 shape",len(X2))
print("X5 shape",len(X5))
print("y shape:", len(y))
print("Vector1 shape:", np.array(vector1).shape)
print("y (df['spam']) length:", len(y))
# Out:
# X1 shape: 5728
# X2 shape 5728
# X5 shape 5728
# y shape: 5728
# Vector1 shape: (5728, 100)
# y (df['spam']) length: 5728

# %%
X_train1, X_test1, y_train, y_test = train_test_split(X1, y, test_size=0.2, random_state=42)
X_train2, X_test2, _, _ = train_test_split(X2, y, test_size=0.2, random_state=42)
X_train5, X_test5, _, _ = train_test_split(X5, y, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10, 100],         # Regularization parametresi
    'gamma': ['scale', 0.1, 0.01, 0.001]  # Kernel koefisyanı
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train1, y_train)

# En iyi parametreler ve skor
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# En iyi model ile test verisi üzerinde tahmin
best_model1 = grid_search.best_estimator_
y_pred_best1 = best_model1.predict(X_test1)

# Doğruluk ve rapor
print("Accuracy (Best RBF kernel):", accuracy_score(y_test, y_pred_best1))
print("Classification Report (Best RBF kernel):\n", classification_report(y_test, y_pred_best1))
# Out:
# Best parameters: {'C': 10, 'gamma': 0.1}
# Best cross-validation accuracy: 0.9777378293562167
# Accuracy (Best RBF kernel): 0.974694589877836
# Classification Report (Best RBF kernel):
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       856
#            1       0.96      0.94      0.95       290
#
#     accuracy                           0.97      1146
#    macro avg       0.97      0.96      0.97      1146
# weighted avg       0.97      0.97      0.97      1146

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],         # Regularization parametresi
    'gamma': ['scale', 0.1, 0.01, 0.001]  # Kernel koefisyanı
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train2, y_train)

# En iyi parametreler ve skor
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# En iyi model ile test verisi üzerinde tahmin
best_model2 = grid_search.best_estimator_
y_pred_best2 = best_model2.predict(X_test2)

# Doğruluk ve rapor
print("Accuracy (Best RBF kernel):", accuracy_score(y_test, y_pred_best2))
print("Classification Report (Best RBF kernel):\n", classification_report(y_test, y_pred_best2))
# Out:
# Best parameters: {'C': 10, 'gamma': 0.1}
# Best cross-validation accuracy: 0.9790466825084646
# Accuracy (Best RBF kernel): 0.9764397905759162
# Classification Report (Best RBF kernel):
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       856
#            1       0.97      0.94      0.95       290
#
#     accuracy                           0.98      1146
#    macro avg       0.97      0.96      0.97      1146
# weighted avg       0.98      0.98      0.98      1146

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],         # Regularization parametresi
    'gamma': ['scale', 0.1, 0.01, 0.001]  # Kernel koefisyanı
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train5, y_train)

# En iyi parametreler ve skor
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# En iyi model ile test verisi üzerinde tahmin
best_model5 = grid_search.best_estimator_
y_pred_best5 = best_model5.predict(X_test5)

# Doğruluk ve rapor
print("Accuracy (Best RBF kernel):", accuracy_score(y_test, y_pred_best5))
print("Classification Report (Best RBF kernel):\n", classification_report(y_test, y_pred_best5))
# Out:
# Best parameters: {'C': 10, 'gamma': 0.1}
# Best cross-validation accuracy: 0.9770828075221555
# Accuracy (Best RBF kernel): 0.9781849912739965
# Classification Report (Best RBF kernel):
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       856
#            1       0.97      0.94      0.96       290
#
#     accuracy                           0.98      1146
#    macro avg       0.98      0.96      0.97      1146
# weighted avg       0.98      0.98      0.98      1146
