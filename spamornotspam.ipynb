# %% [markdown]
# <a href="https://colab.research.google.com/github/bilgekagansenol/SpamornotSpamproject/blob/main/spamornotspam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt',force=True)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os

file_path = r"/content/drive/MyDrive/spamornotspamproject/emails/emails.csv"
if os.path.isfile(file_path):
    print("folder is found")
else:
    print("path is wrong or folder is not exist")
# Out:
# folder is found

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['tokenized_text'] = df['text'].apply(nltk.word_tokenize)

# %%
df.head()
# Out:
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [Subject, :, naturally, irresistible, your, co...
# 1  [Subject, :, the, stock, trading, gunslinger, ...
# 2  [Subject, :, unbelievable, new, homes, made, e...
# 3  [Subject, :, 4, color, printing, special, requ...
# 4  [Subject, :, do, not, have, money, ,, get, sof...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import os
# !git clone https://github.com/bilgekagansenol/SpamornotSpamproject

os.chdir('/content/SpamornotSpamproject')
# Out:
# Cloning into 'SpamornotSpamproject'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 43 (delta 19), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 230.96 KiB | 2.78 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# !ls
# Out:
# functions_cleaning_tokens.py  __pycache__	   SpamornotSpamproject
# functions.ipynb		      spamornotspam.ipynb

# %%
import functions_cleaning_tokens

df['tokenized_text'] = df['tokenized_text'].apply(functions_cleaning_tokens.clean_tokens)
df.head()
# Out:
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [subject, naturally, irresistible, your, corpo...
# 1  [subject, the, stock, trading, gunslinger, fan...
# 2  [subject, unbelievable, new, homes, made, easy...
# 3  [subject, color, printing, special, request, a...
# 4  [subject, do, not, have, money, get, software,...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
pip install pyspellchecker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 42.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from spellchecker import SpellChecker
import nltk

# Gerekli indirmeler
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Tanımlar
stopwords1 = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
spell = SpellChecker()

def correct_spelling(tokens):
    return [spell.correction(token) for token in tokens]

def lemmatize_tokens(tokens):
    # Yazım hatalarını düzelt
    tokens = correct_spelling(tokens)
    # Stopwords kaldır
    tokens = [token for token in tokens if token not in stopwords1]
    # Lemmatization uygula
    return [lemmatizer.lemmatize(token) for token in tokens]

# Lemmatize işlemini uygula
df['tokenized_text'] = df['tokenized_text'].apply(correct_spelling)

print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-aaaa6f542d2a> in <cell line: 29>()
#      27
#      28 # Lemmatize işlemini uygula
# ---> 29 df['tokenized_text'] = df['tokenized_text'].apply(correct_spelling)
#      30
#      31 print(df.head())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
# ...
