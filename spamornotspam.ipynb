# %% [markdown]
# <a href="https://colab.research.google.com/github/bilgekagansenol/SpamornotSpamproject/blob/main/spamornotspam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt',force=True)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os

file_path = r"/content/drive/MyDrive/spamornotspamproject/emails/emails.csv"
if os.path.isfile(file_path):
    print("folder is found")
else:
    print("path is wrong or folder is not exist")
# Out:
# folder is found

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['tokenized_text'] = df['text'].apply(nltk.word_tokenize)

# %%
df.head()
# Out:
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [Subject, :, naturally, irresistible, your, co...
# 1  [Subject, :, the, stock, trading, gunslinger, ...
# 2  [Subject, :, unbelievable, new, homes, made, e...
# 3  [Subject, :, 4, color, printing, special, requ...
# 4  [Subject, :, do, not, have, money, ,, get, sof...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import os
# !git clone https://github.com/bilgekagansenol/SpamornotSpamproject

os.chdir('/content/SpamornotSpamproject')
# Out:
# fatal: destination path 'SpamornotSpamproject' already exists and is not an empty directory.

# %%
# !ls
# Out:
# functions_cleaning_tokens.py  __pycache__	   SpamornotSpamproject  word2vec2.model
# functions.ipynb		      spamornotspam.ipynb  word2vec1.model	 word2vec5.model

# %%
import functions_cleaning_tokens

df['tokenized_text'] = df['tokenized_text'].apply(functions_cleaning_tokens.clean_tokens)
df.head()
# Out:
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [subject, naturally, irresistible, your, corpo...
# 1  [subject, the, stock, trading, gunslinger, fan...
# 2  [subject, unbelievable, new, homes, made, easy...
# 3  [subject, color, printing, special, request, a...
# 4  [subject, do, not, have, money, get, software,...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk


nltk.download('stopwords')

stopwords1 = stopwords.words('english')
print(stopwords1)
list_of_tokens  = []
list_of_tokens = df['tokenized_text'].tolist()
cleaned_samples = [sample[1:] if sample and sample[0].lower() == 'subject' else sample for sample in list_of_tokens]
list_of_tokens = cleaned_samples
list_of_tokens = [token for token in list_of_tokens if token not in stopwords1 ]
df['tokenized_text'] = list_of_tokens
df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#                                                 text  spam  \
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
#
#                                       tokenized_text
# 0  [naturally, irresistible, your, corporate, ide...
# 1  [the, stock, trading, gunslinger, fanny, is, m...
# 2  [unbelievable, new, homes, made, easy, im, wan...
# 3  [color, printing, special, request, additional...
# 4  [do, not, have, money, get, software, cds, fro...

# %%
# !pip install gensim
from gensim.models import Word2Vec
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
model1 = Word2Vec(sentences=mails, vector_size=100, window=5, min_count=1, workers=4)
model2 = Word2Vec(sentences=mails, vector_size=100, window=5, min_count=2, workers=4)
model5= Word2Vec(sentences=mails, vector_size=100, window=5, min_count=5, workers=4)
model1.save("word2vec1.model")
model2.save("word2vec2.model")
model5.save("word2vec5.model")

# %%
import pandas as pd
mails = df['tokenized_text'].tolist()
model1 = Word2Vec.load("word2vec1.model")
model2 = Word2Vec.load("word2vec2.model")
model5 = Word2Vec.load("word2vec5.model")

def word2vec_vector(mails , model):
  vector_tokens = []
  for mail in mails:
    vectors = []
    for token in mail:
      if token in model.wv:
        vectors.append(model.wv[token])
      if len(vectors) >0:
        vector_tokens.append(np.mean(vectors, axis = 0))
      else:
        vector_tokens.append(np.zeros(model.vector_size))
  return vector_tokens

vector1 = word2vec_vector(mails,model1)
vector2 = word2vec_vector(mails,model2)
vector5 = word2vec_vector(mails,model5)

# %%
import numpy as np
np.save('/content/drive/MyDrive/spamornotspamproject/vector1.npy',vector1)
np.save('/content/drive/MyDrive/spamornotspamproject/vector2.npy',vector2)
np.save('/content/drive/MyDrive/spamornotspamproject/vector5.npy',vector5)

# %%
import numpy as np

# vector1'in her öğesinin sabit boyutlu olduğundan emin olun
print(type(vector1))  # list olmalı
print(type(vector1[0]))  # numpy.ndarray olmalı
print(vector1[0].shape)  # (vector_size,) şeklinde sabit boyutta olmalı
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (100,)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
saved_vector1 = np.load('/content/drive/MyDrive/spamornotspamproject/vector1.npy')
saved_vector2 = np.load('/content/drive/MyDrive/spamornotspamproject/vector1.npy')
saved_vector5 = np.load('/content/drive/MyDrive/spamornotspamproject/vector1.npy')
X1 = saved_vector1
X2 = saved_vector2
X5 = saved_vector5
print("X1 shape:", len(X1))
print("y shape:", len(y))
print("Vector1 shape:", np.array(saved_vector1).shape)
print("Vector2 shape:", np.array(saved_vector2).shape)
print("Vector5 shape:", np.array(saved_vector5).shape)
print("y (df['spam']) length:", len(y))
# Out:
# X1 shape: 1299444
# y shape: 5728
# Vector1 shape: (1299444, 100)
# Vector2 shape: (1299444, 100)
# Vector5 shape: (1299444, 100)
# y (df['spam']) length: 5728

# %%
y=df['spam'].tolist()
print(len(y))
# Out:
# 5728

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y, test_size=0.2, random_state=42)
X_train2, X_test2, _, _ = train_test_split(X2, y, test_size=0.2, random_state=42)
X_train5, X_test5, _, _ = train_test_split(X5, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-8d9e4cc2b2e0> in <cell line: 1>()
# ----> 1 X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y, test_size=0.2, random_state=42)
#       2 X_train2, X_test2, _, _ = train_test_split(X2, y, test_size=0.2, random_state=42)
#       3 X_train5, X_test5, _, _ = train_test_split(X5, y, test_size=0.2, random_state=42)
#       4
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2780         raise ValueError("At least one array required as input")
#    2781
# -> 2782     arrays = indexable(*arrays)
#    2783
#    2784     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     512
#     513     result = [_make_indexable(X) for X in iterables]
# --> 514     check_consistent_length(*result)
#     515     return result
#     516
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     455     uniques = np.unique(lengths)
#     456     if len(uniques) > 1:
# --> 457         raise ValueError(
#     458             "Found input variables with inconsistent numbers of samples: %r"
#     459             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1299444, 5728]

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10, 100],         # Regularization parametresi
    'gamma': ['scale', 0.1, 0.01, 0.001]  # Kernel koefisyanı
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train1, y_train1)

# En iyi parametreler ve skor
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# En iyi model ile test verisi üzerinde tahmin
best_model1 = grid_search.best_estimator_
y_pred_best1 = best_model1.predict(X_test1)

# Doğruluk ve rapor
print("Accuracy (Best RBF kernel):", accuracy_score(y_test1, y_pred_best1))
print("Classification Report (Best RBF kernel):\n", classification_report(y_test1, y_pred_best1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ab6eabf2136f> in <cell line: 9>()
#       7
#       8 grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
# ----> 9 grid_search.fit(X_train1, y_train1)
#      10
#      11 # En iyi parametreler ve skor
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
#    1021             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1571     def _run_search(self, evaluate_candidates):
#    1572         """Search all candidates in param_grid"""
# -> 1573         evaluate_candidates(ParameterGrid(self.param_grid))
#    1574
#    1575
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     994                     )
#     995
# --> 996                 _warn_or_raise_about_fit_failures(out, self.error_score)
#     997
#     998                 # For callable self.scoring, the return type is only know after
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _warn_or_raise_about_fit_failures(results, error_score)
#     527                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     528             )
# --> 529             raise ValueError(all_fits_failed_message)
#     530
#     531         else:
#
# ValueError:
# All the 80 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py", line 190, in fit
#     X, y = self._validate_data(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1301, in check_X_y
#     X = check_array(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1012, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 745, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3665,) + inhomogeneous part.
#
# --------------------------------------------------------------------------------
# 48 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py", line 190, in fit
#     X, y = self._validate_data(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1301, in check_X_y
#     X = check_array(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1012, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 745, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3666,) + inhomogeneous part.

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],         # Regularization parametresi
    'gamma': ['scale', 0.1, 0.01, 0.001]  # Kernel koefisyanı
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train2, y_train1)

# En iyi parametreler ve skor
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# En iyi model ile test verisi üzerinde tahmin
best_model2 = grid_search.best_estimator_
y_pred_best2 = best_model2.predict(X_test2)

# Doğruluk ve rapor
print("Accuracy (Best RBF kernel):", accuracy_score(y_test1, y_pred_best2))
print("Classification Report (Best RBF kernel):\n", classification_report(y_test1, y_pred_best2))

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],         # Regularization parametresi
    'gamma': ['scale', 0.1, 0.01, 0.001]  # Kernel koefisyanı
}

grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train5, y_train1)

# En iyi parametreler ve skor
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# En iyi model ile test verisi üzerinde tahmin
best_model5 = grid_search.best_estimator_
y_pred_best5 = best_model.predict(X_test5)

# Doğruluk ve rapor
print("Accuracy (Best RBF kernel):", accuracy_score(y_test1, y_pred_best5))
print("Classification Report (Best RBF kernel):\n", classification_report(y_test1, y_pred_best5))
